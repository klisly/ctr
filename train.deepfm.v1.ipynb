# %%
import numpy as np
import pandas as pd
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sbn
import os
from functools import cmp_to_key
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import plot_model
from deepctr.inputs import SparseFeat, DenseFeat, VarLenSparseFeat, get_feature_names
from deepctr.models import xDeepFM
import pickle
import time
# %matplotlib inline

# %%
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
def load_dict_from_file(file, type='default', skiprow = 0):
    data = list()
    size = 0
    with open(file, encoding='utf-8') as f:
        for line in f:
            size += 1
            try:
                if size <= skiprow:
                    continue
                line = line.replace('"', '').strip()
                if len(line) <= 0:
                    continue
                if type == 'interet':
                    parts = line.split(",")
                    name = parts[0]
                    size = int(parts[1])
                    if size > 10 and len(name) > 0:
                        data.append(name)
                elif type == 'loc':
                    parts = line.split(",")
                    province = parts[0]
                    city = parts[1]
                    area = parts[2]
                    data.append(province)
                    data.append(province + "_" + city)
                    data.append(province + "_" + city + "_" + area)
                elif type == 'publisher':
                    parts = line.split(",")
                    name = parts[0]
                    size = int(parts[1])
                    if size > 10:
                        data.append(name)
                else:
                    data.append(line)
            except:
                print(line)
    return data

# %%
def load_dict(dir, type='default', skiprow = 0):
    data = list()
    size = 0
    files = os.listdir(dir)
    for file in files:
        if not file.endswith(".csv"):
            continue
        data+=load_dict_from_file(dir + "/" + file, type, skiprow)
    return data

# %%
lbe_file = 'lbe.pickle'
data_map_file = 'data_map.pickle'

# %%
def save_pickle_data(file, data):
    f = open(file, 'wb')
    pickle.dump(data, f)
    f.close()


def load_pickle_data(file):
    try:
        f1 = open(file, 'rb')
        return pickle.load(f1)
    except:
        pass
    return None

# %%
def gen_dict_map(vocad):
        its_index = dict()
        size = 0
        for i in vocad:
            if i not in its_index.keys():
                its_index[i] = size
                size += 1
        return its_index

# %%
its = load_dict('/home/recsys/dataset/dict/interets', 'interet')
locs = load_dict('/home/recsys/dataset/dict/loc', 'loc')
publishers = load_dict('/home/recsys/dataset/dict/publisher', 'publisher', 1)
cates = load_dict_from_file('/home/recsys/dataset/dict/cate.csv', 'cate', 1)
channels = load_dict_from_file('/home/recsys/dataset/dict/channel.csv', 'channel', 1)
publishers.append('other')
channels.append('')

u_levels = [str(i) for i in range(0, 10)]
media_levels = [str(i) for i in range(0, 10)]
rschannles = [str(i) for i in range(1, 33)]
vocabs = dict()
vocabs['u_level'] = u_levels
vocabs['t_channel'] = channels
vocabs['cp_category'] = cates
vocabs['cp_publisher'] = publishers
vocabs['cp_media_level'] = media_levels
vocabs['rschannles'] = rschannles
# Out:
# Sky game
# 中国新闻网,绥芬河政府网站,1
# Ansun Biopharma, Inc.,1

# %%
cate_map = gen_dict_map(cates)

# %%
if os.path.exists(lbe_file) and os.path.exists(data_map_file):
    print('load data from cache')
    lbe_pickle = load_pickle_data(lbe_file)
    data_map_pickle = load_pickle_data(data_map_file)

    if lbe_pickle:
        lbes = lbe_pickle
    if data_map_pickle:
        rschannlemap = data_map_pickle['rschannlemap']
        itsmap = data_map_pickle['itsmap']
        locmap = data_map_pickle['locmap']
else:
    def gen_label_encode(vocab):
        lbe = LabelEncoder()
        lbe.fit(vocab)
        return lbe


    lbes = dict()
    for key in vocabs.keys():
        lbes[key] = gen_label_encode(vocabs[key])

    for key in vocabs.keys():
        print(len(vocabs[key]))


    def gen_dict_map(vocad):
        its_index = dict()
        size = 0
        for i in vocad:
            if i not in its_index.keys():
                its_index[i] = size
                size += 1
        return its_index


    rschannles = [str(i) for i in range(1, 33)]
    rschannlemap = gen_dict_map(rschannles)

    itsmap = gen_dict_map(its)
    locmap = gen_dict_map(locs)

    data_map = {}
    data_map['rschannlemap'] = rschannlemap
    data_map['itsmap'] = itsmap
    data_map['locmap'] = locmap
    save_pickle_data(lbe_file, lbes)
    save_pickle_data(data_map_file, data_map)
# Out:
# load data from cache

# %%
len(vocabs)
# Out:
# 6

# %%
dir = '/home/recsys/dataset/train_csv_v1'

# %%
def list_sort_files(dir):
    def compare(x, y):
        stat_x = int(x.replace('-', ''))
        stat_y = int(y.replace('-', ''))
        if stat_x < stat_y:
            return -1
        elif stat_x > stat_y:
            return 1
        else:
            return 0
    items = os.listdir(dir)
    items.sort(key = cmp_to_key(compare))
    return items

# %%
print(list_sort_files(dir)[0])
# Out:
# 2020-05-15-00

# %%
def load_corpus(path):
    files = os.listdir(path)
    final_file = None
    for file in files:
        if file.endswith('.csv'):
            final_file = path +"/"+file
            break
    if not final_file:
        return None
    print('load data from ', final_file)
    return pd.read_csv(final_file)

# %%
def parser_publisher(item):
    if item not in publishers:
        item = 'other'
    return item

# %%
def trans_data(item):
    item['t_channel'] = item['t_channel'].fillna("")
    item['t_location'] = item['t_location'].fillna("")
    item['t_scene'] = item['t_scene'].fillna("")
    item['u_umi_interest'] = item['u_umi_interest'].fillna('')
    item['u_umi_interest_weight'] = item['u_umi_interest_weight'].astype('str').fillna('')
    item['u_umi_cate'] = item['u_umi_cate'].fillna('')
    item['u_umi_cate_weight'] = item['u_umi_cate_weight'].astype('str').fillna('')
    item['u_uli_interest'] = item['u_uli_interest'].fillna('')
    item['u_uli_interest_weight'] = item['u_uli_interest_weight'].astype('str').fillna('')
    item['u_uli_cate'] = item['u_uli_cate'].fillna('')
    item['u_uli_cate_weight'] = item['u_uli_cate_weight'].astype('str').fillna('')
    item['u_usi_interest'] = item['u_usi_interest'].fillna('')
    item['u_usi_interest_weight'] = item['u_usi_interest_weight'].astype('str').fillna('')
    item['u_usi_cate'] = item['u_usi_cate'].fillna('')
    item['u_usi_cate_weight'] = item['u_usi_cate_weight'].astype('str').fillna('')
    item['u_level'] = item['u_level'].fillna(0).astype('str')
    item['cp_media_level'] = item['cp_media_level'].fillna(0).astype('int').astype('str')
    item['cp_publisher'] = item['cp_publisher'].apply(parser_publisher)
    item['cp_location'] = item['cp_location'].fillna("")
    item['cp_location_weight'] = item['cp_location_weight'].fillna("")
    item['cp_category'] = item['cp_category'].fillna('')
    item['cp_category_weight'] = item['cp_category_weight'].astype('str').fillna('')
    item['cp_interests'] = item['cp_interests'].fillna('')
    item['cp_interests_weight'] = item['cp_interests_weight'].astype('str').fillna('')
    item['rs_channel'] = item['rs_channel'].fillna("")
    item['rs_tag_interest'] = item['rs_tag_interest'].fillna('')
    item['rs_tag_interest_dactr'] = item['rs_tag_interest_dactr'].astype('str').fillna('')
    item['rs_tag_cate'] = item['rs_tag_cate'].fillna('')
    item['rs_tag_cate_dactr'] = item['rs_tag_cate_dactr'].astype('str').fillna('')

# %%
file = '2020-05-21-18'
train_corpus = load_corpus('/home/recsys/dataset/train_csv_v1/' + file + '/train')
test_corpus = load_corpus('/home/recsys/dataset/train_csv_v1/' + file + '/test')
cur = int(time.time())
choose_data =  pd.concat([train_corpus, test_corpus])
# Out:
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-18/train/part-00000-f23867b5-57c8-40d8-98b1-fee2456c562a-c000.csv
# /home/recsys/.pyenv/versions/3.6.10/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-18/test/part-00000-d8afc62f-ef33-49eb-8086-d5af7504d48b-c000.csv

# %%
def split_weight(x):
    key_ans = x.split(',')
    return list([float(item) for item in key_ans])

# %%
def gen_pad_seq(values, weights, key2index, max_len=None):
    def split(x):
        vkeys = list()
        try:
            key_ans = set(x.split(','))
            for key in key_ans:
                key = key.strip()
                if len(key) > 0 and key in key2index:
                    vkeys.append(key)
        except:
            pass
        return list(map(lambda x: key2index[x], vkeys))
    def split_weight(x):
        res = list()
        size = 0
        parts = x.split(',')
        for part in parts:
            try:
                if part != 'nan':
                    res.append(float(part))
                else:
                    res.append(0)
                size += 1
            except:
                res.append(0)
                size += 1
        while size < max_len:
            res.append(0)
            size += 1
        return res
    index_list = list(map(split, values))
    weight_list = None
    if weights is not None:
        weight_list = list(map(split_weight, weights))
    index_list = pad_sequences(index_list, maxlen=max_len, padding='post', )
    return index_list, weight_list

# %% [markdown]
# ###### 选择特征列
# uid, u_level, u_umi_interest, u_umi_interest_weight, u_umi_cate, u_umi_cate_weight, u_uli_interest, u_uli_interest_weight, u_uli_cate, u_uli_cate_weight, u_usi_interest, u_usi_interest_weight, u_usi_cate, u_usi_cate_weight
#
# t_channel, t_location
#
# item_id, cp_publisher, cp_media_level, cp_life_hour, cp_newsy_score, cp_word_count, cp_category, cp_category_weight, cp_interests, cp_interests_weight, cp_location, cp_location_weight, cp_is_local, cp_is_local_publisher
#
# rs_p1_score, rs_gactr, rs_channel, rs_tag_interest, rs_tag_interest_dactr, rs_tag_cate, rs_tag_cate_dactr

# %%
# sparse_features = ['u_level', 't_channel', 'cp_publisher', 'cp_media_level']
# dense_features = ['rs_gactr', 'rs_p1_score', 'cp_newsy_score', 'cp_is_local', 'cp_is_local_publisher', 'cp_life_hour', 'cp_word_count']
sparse_features = ['u_level', 't_channel', 'cp_publisher', 'cp_media_level']
dense_features = ['rs_gactr', 'rs_p1_score', 'cp_newsy_score']
target = ['action']

# %%
interest_len = 500
cate_len = 50
cp_interest_len = 10
cp_cate_len = 4
loc_len = 2
rs_tag_len = 10
rs_channel_len = 32
rs_cate_len = 5
rs_its_len = 10

# %%
emb_size = 16

var_info = list()
var_info.append({'label':'u_uli_interest', 'len':interest_len, 'map':itsmap, 'weight':None, 'emb_size':emb_size})
# var_info.append({'label':'u_umi_interest', 'len':interest_len, 'map':itsmap, 'weight':None, 'emb_size':emb_size})
# var_info.append({'label':'u_usi_interest', 'len':interest_len, 'map':itsmap, 'weight':None, 'emb_size':emb_size})
var_info.append({'label':'u_uli_cate', 'len':cate_len, 'map':cate_map, 'weight':None, 'emb_size':emb_size})
# var_info.append({'label':'u_umi_cate', 'len':cate_len, 'map':cate_map, 'weight':None, 'emb_size':emb_size})
# var_info.append({'label':'u_usi_cate', 'len':cate_len, 'map':cate_map, 'weight':None, 'emb_size':emb_size})
var_info.append({'label':'cp_interests', 'len':cp_interest_len, 'map':itsmap, 'weight':None, 'emb_size':emb_size})
var_info.append({'label':'cp_category', 'len':cp_cate_len, 'map':cate_map, 'weight':None, 'emb_size':emb_size})
var_info.append({'label':'cp_location', 'len':loc_len, 'map':locmap, 'weight':None, 'emb_size':emb_size})
var_info.append({'label':'t_location', 'len':loc_len, 'map':locmap, 'weight':None, 'emb_size':emb_size})
var_info.append({'label':'rs_channel', 'len':rs_channel_len, 'map':rschannlemap, 'weight':None, 'emb_size':emb_size})
var_info.append({'label':'rs_tag_interest', 'len':rs_its_len, 'map':itsmap, 'weight':None, 'emb_size':emb_size})
var_info.append({'label':'rs_tag_cate', 'len':rs_cate_len, 'map':cate_map, 'weight':None, 'emb_size':emb_size})

# %%
fixlen_feature_columns = [SparseFeat(feat, vocabulary_size=len(vocabs[feat]), embedding_dim=emb_size)
                              for feat in sparse_features] + [DenseFeat(feat, 1, ) for feat in dense_features]
varlen_feature_columns = []
varlen_feature_columns = [VarLenSparseFeat(SparseFeat(item['label'], vocabulary_size=len(item['map']) + 1, embedding_dim=item['emb_size']), maxlen=item['len'], combiner='mean', weight_name=item['weight']) for item in var_info]
linear_feature_columns = fixlen_feature_columns + varlen_feature_columns
dnn_feature_columns = fixlen_feature_columns + varlen_feature_columns
feature_names = get_feature_names(linear_feature_columns + dnn_feature_columns)

# %%
fixlen_feature_columns
# Out:
# [SparseFeat(name='u_level', vocabulary_size=10, embedding_dim=16, use_hash=False, dtype='int32', embedding_name='u_level', group_name='default_group'),
#  SparseFeat(name='t_channel', vocabulary_size=18, embedding_dim=16, use_hash=False, dtype='int32', embedding_name='t_channel', group_name='default_group'),
#  SparseFeat(name='cp_publisher', vocabulary_size=32414, embedding_dim=16, use_hash=False, dtype='int32', embedding_name='cp_publisher', group_name='default_group'),
#  SparseFeat(name='cp_media_level', vocabulary_size=10, embedding_dim=16, use_hash=False, dtype='int32', embedding_name='cp_media_level', group_name='default_group'),
#  DenseFeat(name='rs_gactr', dimension=1, dtype='float32'),
#  DenseFeat(name='rs_p1_score', dimension=1, dtype='float32'),
#  DenseFeat(name='cp_newsy_score', dimension=1, dtype='float32')]

# %%
model = xDeepFM(linear_feature_columns, dnn_feature_columns, task='binary')
model.compile("adam", "binary_crossentropy", metrics=['binary_crossentropy', 'binary_accuracy', tf.keras.metrics.AUC()])

# %%
def lower_sample_data(df, most_label,  percent=1):
    '''
    percent:多数类别下采样的数量相对于少数类别样本数量的比例
    '''
    most_data = df[df['action'] == most_label]  # 多数类别的样本
    minority_data = df[df['action'] != most_label]  # 少数类别的样本
    index = np.random.randint(len(most_data), size=int(percent *len(minority_data)) )
    #下采样后数据样本
    lower_data = most_data.iloc[list(index)]  # 下采样
    return(pd.concat([lower_data, minority_data]))

# %%
from sklearn.utils import shuffle

# %%
def load_data_from_files(files):
    corpus = []
    for file in files:
        train_corpus = load_corpus('/home/recsys/dataset/train_csv_v1/' + file + '/train')
        test_corpus = load_corpus('/home/recsys/dataset/train_csv_v1/' + file + '/test')
        corpus.append(train_corpus)
        corpus.append(test_corpus)
    return lower_sample_data(pd.concat(corpus), 0, 1)

# %%
def train_by_batch(files):
    file = files[0]
    cur = int(time.time())
    choose_data =  load_data_from_files(files)
    choose_data['u_interests'] = choose_data['u_uli_interest']+","+choose_data['u_umi_interest']+","+choose_data['u_usi_interest']
    choose_data['u_cates'] = choose_data['u_uli_cate']+","+choose_data['u_umi_cate']+","+choose_data['u_usi_cate']
    choose_data = shuffle(choose_data)
    print("concat data cost", (int(time.time()) - cur), 'choose data size:', len(choose_data), 'pos size:', len(choose_data[choose_data['action'] == 1]), 'neg size:', len(choose_data[choose_data['action'] != 1]))
    cur = int(time.time())
    trans_data(choose_data)
    print("trans_data cost", (int(time.time()) - cur))
    for feat in sparse_features:
        lbe = lbes[feat]
        choose_data[feat] = lbe.transform(choose_data[feat])
    cur = int(time.time())
    u_uli_interest_list, u_uli_interest_list_weight = gen_pad_seq(choose_data['u_interests'], None, itsmap, interest_len)
#     u_umi_interest_list, u_umi_interest_list_weight = gen_pad_seq(choose_data['u_umi_interest'], None, itsmap, interest_len)
#     u_usi_interest_list, u_usi_interest_list_weight = gen_pad_seq(choose_data['u_usi_interest'], None, itsmap, interest_len)
    u_uli_cate_list, u_uli_cate_list_weight = gen_pad_seq(choose_data['u_cates'], None, cate_map, cate_len)
#     u_umi_cate_list, u_umi_cate_list_weight = gen_pad_seq(choose_data['u_umi_cate'], None, cate_map, cate_len)
#     u_usi_cate_list, u_usi_cate_list_weight = gen_pad_seq(choose_data['u_usi_cate'], None, cate_map, cate_len)
    cp_interests_list, cp_interests_weight = gen_pad_seq(choose_data['cp_interests'], None, itsmap, cp_interest_len)
    cp_category_list, cp_category_weight = gen_pad_seq(choose_data['cp_category'], None, cate_map, cp_cate_len)
    cp_location_list, cp_location_weight = gen_pad_seq(choose_data['cp_location'], None, locmap, loc_len)
    t_location_list, t_location_weight = gen_pad_seq(choose_data['t_location'], None, locmap, loc_len)
    rs_channel_list, rs_channel_weight = gen_pad_seq(choose_data['rs_channel'], None, rschannlemap, rs_channel_len)
    rs_tag_interest_list, rs_tag_interest_weight = gen_pad_seq(choose_data['rs_tag_interest'], None, itsmap, rs_its_len)
    rs_tag_cate_list, rs_tag_cate_weight = gen_pad_seq(choose_data['rs_tag_cate'], None, cate_map, rs_cate_len)
    print("pad data cost", (int(time.time()) - cur))
    var_data = list()
    var_data.append({'label':'u_uli_interest', 'list':u_uli_interest_list, 'weight':None})
#     var_data.append({'label':'u_umi_interest', 'list':u_umi_interest_list, 'weight':None})
#     var_data.append({'label':'u_usi_interest', 'list':u_usi_interest_list, 'weight':None})
    var_data.append({'label':'u_uli_cate', 'list':u_uli_cate_list, 'weight':None})
#     var_data.append({'label':'u_umi_cate', 'list':u_umi_cate_list, 'weight':None})
#     var_data.append({'label':'u_usi_cate', 'list':u_usi_cate_list, 'weight':None})
    var_data.append({'label':'cp_interests', 'list':cp_interests_list, 'weight':None})
    var_data.append({'label':'cp_category', 'list':cp_category_list})
    var_data.append({'label':'cp_location', 'list':cp_location_list})
    var_data.append({'label':'t_location', 'list':t_location_list})
    var_data.append({'label':'rs_channel', 'list':rs_channel_list})
    var_data.append({'label':'rs_tag_interest', 'list':rs_tag_interest_list})
    var_data.append({'label':'rs_tag_cate', 'list':rs_tag_cate_list})

    
    model_input = {name: choose_data[name] for name in feature_names}
    for item in var_data:
        model_input[item['label']] = item['list']
#         if item['label'] == 'u_uli' or item['label'] == 'u_umi' or item['label'] == 'u_usi':
#             model_input[item['label']+'_weight'] = item['weight']
   
    history = model.fit(model_input, choose_data[target].values,
                    batch_size=128, epochs=10, verbose=2, validation_split=0.1, callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_binary_accuracy', patience=1)],)
    model.save_weights('./checkpoints/'+file)

# %%
files = list_sort_files(dir)
tmps = []
size = 0
for file in files:
    size += 1
    tmps.append(file)
#     print('train model use data from ', file)
    if size > 72:
        train_by_batch(tmps)
        tmps = []
        size = 0
if size > 0:
    train_by_batch(tmps)
    size = 0
# Out:
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-00/train/part-00000-fea9d6c6-ce27-478b-8b91-d4a47e366bd4-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-00/test/part-00000-2f154b48-f1b6-4b90-b886-fc2159d8f609-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-01/train/part-00000-28e9dfd3-c37b-4b09-b4d1-a782fb7b5ee4-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-01/test/part-00000-85858532-4699-447f-8fd3-eafeebb3752a-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-02/train/part-00000-9e21bd72-bf86-43c7-847a-272511b64eda-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-02/test/part-00000-f4f2a8a1-55a2-417e-ab43-6bc9b32dfa5d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-03/train/part-00000-51f9b66f-65e2-40f1-bfe0-76c75f5b775e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-03/test/part-00000-c0dec744-3dfb-441e-b6b8-171fd2b80248-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-04/train/part-00000-ce171115-7ffe-4697-ad7f-847e581621f8-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-04/test/part-00000-278cd33b-c9fe-4a56-9f2a-e092a3330bd7-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-05/train/part-00000-2dd86212-8f05-4e18-bf5c-3107c163665b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-05/test/part-00000-bce23be4-be6c-4657-9de4-545a3c553997-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-06/train/part-00000-cf844f3a-e82f-4aac-a8ec-5d419b5fd07a-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-06/test/part-00000-09e5cc5a-dd72-44f5-9664-a2cfaa42acb9-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-07/train/part-00000-528e3e85-f27a-43e6-b187-e4113abc1e06-c000.csv
# /home/recsys/.pyenv/versions/3.6.10/lib/python3.6/site-packages/ipykernel_launcher.py:9: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   if __name__ == '__main__':
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-07/test/part-00000-18ad8f18-df3a-46ad-8c25-9394a52b7034-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-08/train/part-00000-05a4490f-4621-4e40-a8dd-8b20f1be2499-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-08/test/part-00000-4387b142-4feb-4747-a52a-981551ce5d9e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-09/train/part-00000-a221d3f0-1273-454f-875f-7e0c25de33fc-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-09/test/part-00000-bc44a5db-2473-4037-9c43-19816ff5c4af-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-10/train/part-00000-f17d8593-313a-4c67-93a6-870f65e4c379-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-10/test/part-00000-0dc9ce4c-0b43-4f58-b5dd-839cf58f1dc0-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-11/train/part-00000-a2fcea0b-f476-48f6-af4d-6194c152597b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-11/test/part-00000-dd3523dc-2c57-497c-b62d-702e70ed4db4-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-12/train/part-00000-04338d4f-c5b0-40f6-bf7a-0740614fb541-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-12/test/part-00000-c8edaa15-2288-458d-ba61-7788217989be-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-13/train/part-00000-7da7f01b-1445-4b96-bf10-db4f5b90e204-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-13/test/part-00000-700ceace-3ecb-46ae-91b8-e9cc0337231d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-14/train/part-00000-9147f5cd-537d-49c9-a660-5a02550adbc2-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-14/test/part-00000-cc26b05d-9c71-4ffa-a4d8-fc9d9ac22bc1-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-15/train/part-00000-5c326035-45f0-4877-a867-1d152974aa78-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-15/test/part-00000-b8d81546-e1aa-4e91-84e3-f3921aa2cfb7-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-16/train/part-00000-d48da00a-b5ea-4e70-8c3c-bf49e7410462-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-16/test/part-00000-ab0c3ffd-b326-44b8-81cc-3836a2219fb9-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-17/train/part-00000-b5ae87fa-35d6-4271-96a8-64a654aa340e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-17/test/part-00000-0d0c460c-fa89-4a0a-b2fe-d38e86291923-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-18/train/part-00000-5cb67f59-5093-4789-843b-2860c1947f3b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-18/test/part-00000-9bb02599-417f-4933-8f91-bd149db71696-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-19/train/part-00000-48a3ebcd-21b7-4e62-a37a-685920949b8d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-19/test/part-00000-e791d01d-087c-4bcb-ad6d-1de814b14b15-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-20/train/part-00000-2aa9591d-3fd3-4d97-915a-dce050e662ff-c000.csv
# /home/recsys/.pyenv/versions/3.6.10/lib/python3.6/site-packages/ipykernel_launcher.py:9: DtypeWarning: Columns (11,14,15,16,17,18,19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   if __name__ == '__main__':
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-20/test/part-00000-e3b772bb-e936-40ba-8d3a-3412b573a89f-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-21/train/part-00000-21ffe14b-2f68-4cf2-b0da-84fb8139b651-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-21/test/part-00000-a8686962-fb31-4d26-aef9-c4bd3235eb09-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-22/train/part-00000-bed86841-36ad-4771-8e79-790ab96f47eb-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-22/test/part-00000-fd2ab5d8-327d-4cb7-8dd7-45584647c9fb-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-23/train/part-00000-6be1095b-071b-4dd0-aa3d-a8d6fc24b5ec-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-15-23/test/part-00000-ef52a5f3-c3ec-4a9b-8d33-7db22eef6c1c-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-00/train/part-00000-aa88c22a-f819-490a-9e39-836b3a9d9ba5-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-00/test/part-00000-a40cdada-f799-4d02-ae47-9bb360185429-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-01/train/part-00000-ade1a791-ea9d-4002-9b8a-6b9d5f8c5ce1-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-01/test/part-00000-c1b45798-1c0a-4a30-9b26-bdd05ddf01cb-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-02/train/part-00000-454407ff-230f-46f4-9065-82f513a39344-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-02/test/part-00000-e45a6b1c-9b8a-41c1-a1be-f25baf1d6fef-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-03/train/part-00000-4d74fb63-8852-4ee8-b3a7-deb574cf249e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-03/test/part-00000-32056932-5a64-4788-b19f-b8c863c6b83b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-04/train/part-00000-a39e0f9b-b6fb-4c27-8815-0b720b95d7a7-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-04/test/part-00000-b80a6d0b-382a-4bc4-9d6d-7cc842ea3f9e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-05/train/part-00000-19c1f61a-4ef1-4bd3-959d-e5f501ff6563-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-05/test/part-00000-1edcfc6e-a626-4f70-882a-9ac527fd902e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-06/train/part-00000-4281be66-8ec9-429b-8496-7d161a08ab6c-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-06/test/part-00000-21860de2-af32-4876-a76f-ab8c69f5435d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-07/train/part-00000-68b243a3-c831-4c2b-8147-274568213e19-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-07/test/part-00000-b292b522-072a-41e7-a2b7-f06236c9cf4b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-08/train/part-00000-76d6c467-dea6-4f18-b715-9a7488c4cd16-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-08/test/part-00000-af4c9910-e561-4f1c-b85d-3c82c180072e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-09/train/part-00000-368dfb0e-532e-4644-9fd4-c10fec3ccb8c-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-09/test/part-00000-4cb500b6-8412-4b67-8355-5934f429fd6e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-10/train/part-00000-fe416500-064b-48b4-a4c6-3c1bab5ff1f3-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-10/test/part-00000-a7a6cfb3-1f66-4624-9f55-6e4edc2c8171-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-11/train/part-00000-b721ae7a-08c3-43a0-a88d-1eb1c049fc9e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-11/test/part-00000-41d73c02-e898-408d-a27e-a1c7fdc7a75f-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-12/train/part-00000-f7226ef8-e5ae-4b08-977d-26cb4d916249-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-12/test/part-00000-3028f471-ee27-406d-a262-2216fe7cb286-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-13/train/part-00000-35061b20-c508-47fa-911b-7622f429396b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-13/test/part-00000-be47fcbc-7c34-49c1-94ce-39b8c5d1107d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-14/train/part-00000-20cb3785-f082-4e24-bfb6-d56601293e30-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-14/test/part-00000-fabf54e4-f0db-43c5-bc24-66c6511fa711-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-15/train/part-00000-157154f9-99f4-485a-803c-f225f6437ac8-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-15/test/part-00000-2e5c8f17-d331-4d6d-a77c-238d7489ff74-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-16/train/part-00000-1a773314-346e-422a-a46c-f8114041cf08-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-16/test/part-00000-7aae6f28-a7e2-4042-bb93-37e7779f5028-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-17/train/part-00000-ed91babb-9d5d-4151-905f-d68a664e2b1d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-17/test/part-00000-85910e94-7100-46b2-9dda-f4a2c0236f94-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-18/train/part-00000-9d6ff7d3-6178-4a36-94d8-b6988624fae6-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-18/test/part-00000-990d8791-9058-4929-aa33-e645471e3fc0-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-19/train/part-00000-fd3ebb79-df66-4576-a438-b3e6eccdef2a-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-19/test/part-00000-d9e864ca-d4a5-409d-93b1-89065d0d8671-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-20/train/part-00000-af160568-d5bc-44cb-97b3-7816a61eef23-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-20/test/part-00000-e78170fa-55b0-400e-925f-9669cd8f9ae1-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-21/train/part-00000-7dba7f2c-132e-4b8d-b1cc-365737a4176e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-21/test/part-00000-b207bcf9-d6a6-46fa-956c-9f0555bae8c9-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-22/train/part-00000-43cfa8c3-fbe5-41be-a1c9-2fc834eb5f5b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-22/test/part-00000-43f242c8-4c73-4491-a8f6-12fc24132976-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-23/train/part-00000-8162fbfd-039b-41b7-9831-fb76c231e5a6-c000.csv
# /home/recsys/.pyenv/versions/3.6.10/lib/python3.6/site-packages/ipykernel_launcher.py:9: DtypeWarning: Columns (17,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   if __name__ == '__main__':
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-16-23/test/part-00000-52ac8132-db2e-4f46-9c7a-4dd885e077ef-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-00/train/part-00000-fed564a7-fae9-4a54-a2ae-c3b01b54fa1c-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-00/test/part-00000-b7a2eeb9-1e98-4d67-b980-b746b1abd663-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-01/train/part-00000-95233db0-97bf-4f5c-9758-b14247ccd01b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-01/test/part-00000-66ca2c2b-b580-4e80-8218-18affa1497f0-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-02/train/part-00000-71236f0a-e796-4f23-89e6-a489e1672fac-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-02/test/part-00000-e20028e1-e483-48ca-b66a-d110ad0556f1-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-03/train/part-00000-022f5be5-29e2-4d6b-81bd-ba986bd76937-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-03/test/part-00000-bcaec5c4-ab50-46ec-af2c-d421d8306c57-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-04/train/part-00000-55256031-41e9-4889-a321-c22f83a96bdb-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-04/test/part-00000-9a7c5c39-8872-494c-ae3f-2a1616138b49-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-05/train/part-00000-16d7e922-7057-4330-84a6-bdf77bb0ae49-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-05/test/part-00000-447b93e2-461f-4aa9-a36a-12e05f16f21b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-06/train/part-00000-7fadea95-b36b-4bac-abfe-269ea35cb100-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-06/test/part-00000-e3427d98-6f80-4249-a41f-8d36846adb1c-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-07/train/part-00000-e1146eb1-4a15-4f20-b9a9-74a7c21e9ed1-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-07/test/part-00000-10f35096-3c48-4505-b89b-f2a4a47bcf98-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-08/train/part-00000-fda85082-1269-4d68-88c0-92468911c4b4-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-08/test/part-00000-d564d093-aad1-4101-9edb-5605bf77caee-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-09/train/part-00000-6217acf4-1425-4e4a-8019-997c34eec659-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-09/test/part-00000-7ae498fa-0f11-49b4-9c22-4e00a0bffac0-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-10/train/part-00000-24c69e76-a4bf-4790-a377-9b9e3d3373d5-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-10/test/part-00000-41e14711-ae36-46ef-a550-3f670d6be760-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-11/train/part-00000-567ba8eb-13c7-45d3-b4b2-d062bd6dec99-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-11/test/part-00000-1a7ea73a-df11-4303-8e7d-b1860326dbf8-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-12/train/part-00000-ca037800-78ec-4f08-9abf-0274656f74d7-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-12/test/part-00000-0b6ae6a4-acd3-499d-bc78-1e340324e48a-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-13/train/part-00000-30c42e2f-acb6-43b3-a84f-8ef7ceafdc0b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-13/test/part-00000-a238656d-435d-44e8-80ca-d8655a8f0f9c-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-14/train/part-00000-fa73cb97-522d-40d6-9b81-9843ee3ad5de-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-14/test/part-00000-dd954e83-96fb-45e7-81b7-184face291f5-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-15/train/part-00000-c7da90d3-81d7-4256-9e79-f0c2fe5da320-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-15/test/part-00000-6ee7ce34-5fc2-4e69-84ac-aa18d39da232-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-16/train/part-00000-b275a9c8-e8b0-4502-bd90-5e481388cd1f-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-16/test/part-00000-af158e03-e6cd-4031-bb53-12a5f2e8b744-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-17/train/part-00000-b815b779-920c-4294-ad10-de997e587903-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-17-17/test/part-00000-c288d1b0-ff87-4028-a31a-bf23ee5e955e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-18/train/part-00000-f23867b5-57c8-40d8-98b1-fee2456c562a-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-18/test/part-00000-d8afc62f-ef33-49eb-8086-d5af7504d48b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-19/train/part-00000-51c87781-87ac-4afc-a10e-39b45c75e1ed-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-19/test/part-00000-6be890ec-1e2b-4686-8d61-3f99b1d5af4a-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-20/train/part-00000-b56a88f1-7e19-4d45-a22f-71d24922e378-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-20/test/part-00000-7c058209-e125-4a95-94e1-1c5941362aca-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-21/train/part-00000-c64b0009-f343-4c12-864d-36c1671f8412-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-21/test/part-00000-71abff92-72f6-46f3-9d38-6187c6181276-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-22/train/part-00000-65cfac9c-f824-4dc4-b1bb-21e45f802b20-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-22/test/part-00000-5929f994-7d55-4cfd-be25-9a15973a0c92-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-23/train/part-00000-cb68b0a9-622a-4ca3-b52e-86f168038b59-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-23/test/part-00000-1a3e14b5-6e46-4d37-a3e6-1c6e240293de-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-00/train/part-00000-92982d12-b438-477e-81ad-223fc1435eb8-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-00/test/part-00000-2d416525-4deb-493c-b94c-655953a9245e-c000.csv
# concat data cost 406 choose data size: 1613768 pos size: 806884 neg size: 806884
# trans_data cost 514
# pad data cost 291
# Train on 1452391 samples, validate on 161377 samples
# Epoch 1/10
# /home/recsys/.pyenv/versions/3.6.10/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/recsys/.pyenv/versions/3.6.10/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 1452391/1452391 - 524s - loss: 0.6280 - binary_crossentropy: 0.6235 - binary_accuracy: 0.6541 - auc_1: 0.7076 - val_loss: 0.6239 - val_binary_crossentropy: 0.6184 - val_binary_accuracy: 0.6586 - val_auc_1: 0.7141
# Epoch 2/10
# 1452391/1452391 - 514s - loss: 0.6219 - binary_crossentropy: 0.6156 - binary_accuracy: 0.6612 - auc_1: 0.7174 - val_loss: 0.6231 - val_binary_crossentropy: 0.6168 - val_binary_accuracy: 0.6606 - val_auc_1: 0.7167
# Epoch 3/10
# 1452391/1452391 - 519s - loss: 0.6198 - binary_crossentropy: 0.6129 - binary_accuracy: 0.6633 - auc_1: 0.7207 - val_loss: 0.6223 - val_binary_crossentropy: 0.6155 - val_binary_accuracy: 0.6604 - val_auc_1: 0.7178
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-01/train/part-00000-51fdc0ba-66fb-4236-8cd0-edb8e49bd309-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-01/test/part-00000-4b1dc326-d905-4024-88af-932e4d05802f-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-02/train/part-00000-b4f74cea-516d-4107-8b1e-104754e4e29a-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-02/test/part-00000-bec8aa24-e0a5-45d2-950d-492183be8d2e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-03/train/part-00000-5fa481e9-634d-4381-b613-8523e9ac7400-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-03/test/part-00000-455a3b85-0abf-4e7b-a5c9-1ea7a1f7a857-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-04/train/part-00000-e4512cba-c694-446c-b1e8-861c5d06498f-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-04/test/part-00000-7860305a-3b07-4669-8975-00bf12bbd1b3-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-05/train/part-00000-f57215d7-3a7a-4d87-b48f-a1bf7f22161f-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-05/test/part-00000-8fb927bf-3b57-45ec-a92b-6d354f051276-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-06/train/part-00000-e142b38a-3491-44f5-8c58-afec8e49d1b5-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-06/test/part-00000-66d24fd0-501c-4bbf-b32c-3111f2924d80-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-07/train/part-00000-39096869-8fbd-49b3-955b-b15b8efffb0f-c000.csv
# /home/recsys/.pyenv/versions/3.6.10/lib/python3.6/site-packages/ipykernel_launcher.py:9: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   if __name__ == '__main__':
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-07/test/part-00000-34b296cf-85d5-401e-a2d0-9984e3a6e71b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-08/train/part-00000-5a6ef55b-edc3-40e7-96b8-a27e1f1295da-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-08/test/part-00000-9433c1c8-5172-4471-b01b-62c98762f011-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-09/train/part-00000-b3d309ab-456c-46d7-aa6d-038fdc536ce3-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-09/test/part-00000-ca3b9019-5cb2-40bf-a85e-4a30e90e1ea2-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-10/train/part-00000-a6116636-548e-4f39-877c-4b721b1302fb-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-10/test/part-00000-d07bac7f-5a4a-4f6c-a8bd-970813236da6-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-11/train/part-00000-9bfa4eb6-0031-4fdf-8a68-647ec6fe8e07-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-11/test/part-00000-8a32016d-8131-4ff1-9b7b-c00f25949671-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-12/train/part-00000-8f22d299-097d-4e46-8731-a852f65237ac-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-12/test/part-00000-f7bb1140-7c49-44a1-97e7-0819e32e5411-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-13/train/part-00000-3645b027-c369-4906-bc5e-99d3b591b80d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-13/test/part-00000-84cd8af2-8f3a-42b5-9ca6-84c7c2c9e1e6-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-14/train/part-00000-ad4e772c-6f0b-4b22-bedd-27ea9d044cf6-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-14/test/part-00000-77fe17dc-f316-4aa4-bb11-eac51559105e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-15/train/part-00000-76f07f42-30ce-4c81-8226-ac39526ba17d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-15/test/part-00000-81c8371e-5450-4965-a3c0-45e66fd5646e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-16/train/part-00000-88847f8f-faba-4887-ad92-2f3d4553f3e2-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-16/test/part-00000-6fe5d0fb-e469-4cc6-a96d-90609082fbf6-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-17/train/part-00000-07cbe5de-1732-49ab-95a5-6e6f4df86ddc-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-17/test/part-00000-a4cc4609-14b0-4353-898b-d4a71a1d3ea8-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-18/train/part-00000-aa71a979-bca0-4b8f-9698-aa1d63b42582-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-18/test/part-00000-b2b9443a-42be-4c0e-b862-1fee2d8909b9-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-19/train/part-00000-98b9f578-7156-46f2-a853-5542809e5dde-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-19/test/part-00000-16d32ab5-250c-49f8-ad26-d0ad470eff27-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-20/train/part-00000-59b59718-31fb-4706-bdb0-3dacdc2796b9-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-20/test/part-00000-1a3ca592-7ce8-4c51-9693-b58684f32399-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-21/train/part-00000-4312a60e-2542-4f34-8b91-994ae4fdf188-c000.csv
# /home/recsys/.pyenv/versions/3.6.10/lib/python3.6/site-packages/ipykernel_launcher.py:9: DtypeWarning: Columns (11,14,15,16,17,18,19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   if __name__ == '__main__':
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-21/test/part-00000-4cbceab5-a374-43e6-ad13-42e4c3557635-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-22/train/part-00000-20986eaf-949e-47b2-8661-8e70fc215a37-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-22/test/part-00000-26d384fc-2e4f-4751-b288-c2f0d8f2166b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-23/train/part-00000-7bcbaf6b-83d5-414f-a405-21a274c023c5-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-22-23/test/part-00000-ddb196e3-048d-4c8f-8303-cb4bdc0b5799-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-00/train/part-00000-d42629e4-8513-4808-bb1b-5bc10bbc6015-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-00/test/part-00000-bfeefb17-358c-44d7-8f53-1d1c059d54a1-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-01/train/part-00000-e76ecf01-9b11-4d3e-ba29-afb219d1681d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-01/test/part-00000-4481ce53-48a6-4c52-a05e-8ed59e3f860e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-02/train/part-00000-97b9446a-b794-4dce-8a9f-01aba4b0619f-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-02/test/part-00000-31f87a58-98d9-46b7-86bc-f5da1968ecc9-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-03/train/part-00000-3b2cae4f-d48c-494c-b378-bb4ace93169d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-03/test/part-00000-0348d157-618f-4ebb-a632-1b5aa08c14f9-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-04/train/part-00000-44dafc57-5ef0-4b99-9b7a-f41c488b4d85-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-04/test/part-00000-36cd1fa5-2ffd-412b-8ba0-22d8206ca769-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-05/train/part-00000-c5ee43a7-1671-4b7a-9f35-cbdb3283001c-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-05/test/part-00000-2d402da8-c1e2-47a4-8723-1d449bc28e82-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-06/train/part-00000-1fb33324-6c46-494d-82ad-8f7ecd01f4a8-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-06/test/part-00000-eea1a02e-e7ec-4e10-8eb0-38ef54f0756d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-07/train/part-00000-2fc8ea72-3fec-4dfb-88be-22668843badf-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-07/test/part-00000-1d1c13aa-9c16-47d5-a9c1-8b85a968c504-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-08/train/part-00000-a3919dbd-958c-494b-af24-07cc0af6c554-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-08/test/part-00000-96fbfe24-ffcd-4f09-8c07-0bf45abca255-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-09/train/part-00000-097fd2cd-a7cb-43c9-8ef1-f8f23a847542-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-09/test/part-00000-f9ffbe2d-94fd-4c66-b764-d910f87774e1-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-10/train/part-00000-237c4845-c916-4e74-ab7c-9cbebbb57ab5-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-10/test/part-00000-c1bfe9f7-650e-4c47-9967-d75ffd4e0c83-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-11/train/part-00000-666919a3-cbc3-4f5f-9161-1af32600ce6e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-11/test/part-00000-fc0a226e-5476-4883-a3a5-80296bf77b5c-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-12/train/part-00000-4e26f848-8537-4593-8b5d-fbe901679b9c-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-12/test/part-00000-98e19b3c-fdc0-44d0-b96f-e4bb24e8fff1-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-13/train/part-00000-452c2d6e-b30f-4332-b928-a9e55d67d141-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-13/test/part-00000-b21b4e27-e1b2-4127-a68c-89200d60ec95-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-14/train/part-00000-671818c5-3c4a-45a6-870b-6905e7ee6e33-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-14/test/part-00000-2b00d208-93d0-414c-91bd-3319c0a430bc-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-15/train/part-00000-5b9729ee-c2ca-43d4-92ac-c1c5fe95bc6f-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-15/test/part-00000-5b263aed-00e1-486b-939f-8bcfb6e40fed-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-16/train/part-00000-b26e3121-a0a1-4c09-ae00-28eaa6507876-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-16/test/part-00000-52bb8d11-28a0-4bf0-b723-feb64fe14eb0-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-17/train/part-00000-d086e275-8053-4466-b142-f5bab1830d6b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-17/test/part-00000-05f6f67c-b64c-4712-a8d9-11ad66967ff6-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-18/train/part-00000-8ed666c4-2293-47bf-928f-aea300557cb3-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-18/test/part-00000-bc4dc80a-b769-4aa4-a44f-96faa7ed9c26-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-19/train/part-00000-bb80507e-1462-4ee7-8a37-29ad91e08ff5-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-19/test/part-00000-deef4124-d92b-46be-8a1c-32f0c401c5ea-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-20/train/part-00000-8a2a688f-915d-4a31-8d17-3e069907072d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-20/test/part-00000-78b09e4b-d89b-4672-b64a-e9fa820d566e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-21/train/part-00000-8eebb832-f0bc-4756-8610-ffd42e3d8fa9-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-21/test/part-00000-0aac0347-c035-4757-9b8e-2a57b1c921a5-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-22/train/part-00000-96d83643-cec4-45dd-85b7-16d1749786b8-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-22/test/part-00000-219d6f94-8cc2-4fed-8bc2-b57f3e88846c-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-23/train/part-00000-3f559251-684e-4e38-a696-b5eb9726fef7-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-23-23/test/part-00000-5f57a5de-ee8f-4ef7-9b8e-a2af1bed231f-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-00/train/part-00000-6a751eaa-67c6-40dc-b569-845fcd02daaa-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-00/test/part-00000-1480b59c-f888-4b46-86a3-b71653093ce1-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-01/train/part-00000-c3a247e9-d19d-4dfb-9f97-072d732ee230-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-01/test/part-00000-1b61b632-b081-4186-8a18-051496aa3743-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-02/train/part-00000-7572faaf-eae6-4fa0-9ce9-0fc55081b37e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-02/test/part-00000-3ef84ea4-4c26-44e5-a610-449a360b25ba-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-03/train/part-00000-98a4f542-ed34-470e-87c3-c3f1fd6449b1-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-03/test/part-00000-37bbc083-555a-4a7d-9c42-603ee09a6979-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-04/train/part-00000-bf97f642-309b-480e-a563-8c763cb5bbfd-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-04/test/part-00000-c9a13276-ef96-4a9d-b8c4-667f424a1761-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-05/train/part-00000-849b237c-09b1-4f9c-96f7-5d5541ab8c2e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-05/test/part-00000-dde6d904-887e-44ba-818b-87cf2b0fadd2-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-06/train/part-00000-b844d5b1-b2a3-4521-81c4-509ce911b448-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-06/test/part-00000-0d757a82-4933-4624-946f-d6b3a905f15d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-07/train/part-00000-cf16922a-080d-44d9-a74c-83a5e8b259c9-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-07/test/part-00000-ccacf30e-c76f-410f-bb38-24ace8c6d4b9-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-08/train/part-00000-05ddb9d2-79f7-4df2-ba91-d086501f9855-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-08/test/part-00000-d3342376-730c-4e26-b78e-4839495579dc-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-09/train/part-00000-0537e1b6-1bd4-4d56-b3fd-ba06684d3ef2-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-09/test/part-00000-72a6f3b4-5e5b-4a92-b19f-fbe60f2f0829-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-10/train/part-00000-99341f41-74b6-48c1-b60b-4fbedabea7e9-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-10/test/part-00000-a13e9067-71b6-417b-863d-4d910d4bce18-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-11/train/part-00000-aa88a44a-058c-4faa-9c24-598d159dca74-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-11/test/part-00000-db5ce3d0-2862-49b8-a51e-b137f9abef83-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-12/train/part-00000-b2906560-9fa0-443e-bcf3-0703515b8551-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-12/test/part-00000-79040f06-ddbc-4db1-9f43-a345e24ae60f-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-13/train/part-00000-daf0f701-2414-42ad-b4d5-23b9cafa080d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-13/test/part-00000-edd6c481-3172-4b3a-b2f4-294c120ac4fc-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-14/train/part-00000-9df576ae-6981-4337-a1df-93d67f900a3a-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-14/test/part-00000-f0889e68-9138-4d7f-b126-85b79e6a759f-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-15/train/part-00000-72277588-604e-41f8-b51a-481eb9e796c7-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-15/test/part-00000-1c7dcb14-7a75-42bd-8c70-57e76b04b206-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-16/train/part-00000-6ad3a589-24ff-4f35-b5f3-bb256021651b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-16/test/part-00000-b440a416-a371-46cb-8de2-e7873760b4c7-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-17/train/part-00000-b4a1a83e-311c-4c77-b31d-175d2491d7b6-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-17/test/part-00000-0449b24c-224e-4f12-8975-694f00e578cb-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-18/train/part-00000-be1769e1-04cc-4d21-ae7b-63eaf5398e8d-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-18/test/part-00000-efe5b540-d958-4634-9e1e-2af4dbf6a72a-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-19/train/part-00000-cf0cf0fc-c320-487f-aeef-43fb2166f975-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-19/test/part-00000-723de4ed-8c9e-43db-b041-aee0770f87e3-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-20/train/part-00000-c7f26c37-ebd3-4653-9e77-a81d8f7e7277-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-20/test/part-00000-45d38b08-fde9-4ef5-93fa-3bf2e2942d5e-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-21/train/part-00000-2639395a-403b-4bc0-ba9e-c6e5bda3fa01-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-21/test/part-00000-53b8a24a-0810-413e-8c90-a663fd0fa955-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-22/train/part-00000-9b09bad2-4156-4f91-8747-46237a87fd5a-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-22/test/part-00000-4b5ed612-a87d-4574-95ab-c56bcfac2757-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-23/train/part-00000-0f469ccd-4d2d-4e36-aec4-1d396cd761ef-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-24-23/test/part-00000-4e93d73e-2468-4e10-9127-e416d92fcec7-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-25-00/train/part-00000-83ff46a9-7c97-469b-84ae-218832f34383-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-25-00/test/part-00000-dae96cca-e5a0-4f08-916c-b74370c9fa52-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-25-01/train/part-00000-4d36b82c-6008-4b8f-b280-a5c3e972a15b-c000.csv
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-25-01/test/part-00000-f2313b63-047c-4cdc-ac48-fcd5ee116ef2-c000.csv
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-43-8300ae1b4a8a> in <module>
#       7 #     print('train model use data from ', file)
#       8     if size > 72:
# ----> 9         train_by_batch(tmps)
#      10         tmps = []
#      11         size = 0
#
# <ipython-input-41-01eee85beb42> in train_by_batch(files)
#       2     file = files[0]
#       3     cur = int(time.time())
# ----> 4     choose_data =  load_data_from_files(files)
#       5     choose_data['u_interests'] = choose_data['u_uli_interest']+","+choose_data['u_umi_interest']+","+choose_data['u_usi_interest']
#       6     choose_data['u_cates'] = choose_data['u_uli_cate']+","+choose_data['u_umi_cate']+","+choose_data['u_usi_cate']
#
# <ipython-input-40-352e39dada28> in load_data_from_files(files)
#       6         corpus.append(train_corpus)
#       7         corpus.append(test_corpus)
# ----> 8     return lower_sample_data(pd.concat(corpus), 0, 1)
#
# <ipython-input-38-3e654983f42d> in lower_sample_data(df, most_label, percent)
#       3     percent:多数类别下采样的数量相对于少数类别样本数量的比例
#       4     '''
# ----> 5     most_data = df[df['action'] == most_label]  # 多数类别的样本
#       6     minority_data = df[df['action'] != most_label]  # 少数类别的样本
#       7     index = np.random.randint(len(most_data), size=int(percent *len(minority_data)) )
#
# ~/.pyenv/versions/3.6.10/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
#    2793         # We are left with two options: a single key, and a collection of keys,
#
# ~/.pyenv/versions/3.6.10/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2843         key = check_bool_indexer(self.index, key)
#    2844         indexer = key.nonzero()[0]
# -> 2845         return self._take_with_is_copy(indexer, axis=0)
#    2846
#    2847     def _getitem_multilevel(self, key):
#
# ~/.pyenv/versions/3.6.10/lib/python3.6/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis, **kwargs)
#    3407         See the docstring of `take` for full explanation of the parameters.
#    3408         """
# -> 3409         result = self.take(indices=indices, axis=axis, **kwargs)
#    3410         # Maybe set copy if we didn't actually change the index.
#    3411         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~/.pyenv/versions/3.6.10/lib/python3.6/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3390         nv.validate_take(tuple(), kwargs)
#    3391
# -> 3392         self._consolidate_inplace()
#    3393
#    3394         new_data = self._data.take(
#
# ~/.pyenv/versions/3.6.10/lib/python3.6/site-packages/pandas/core/generic.py in _consolidate_inplace(self)
#    5345             self._data = self._data.consolidate()
#    5346
# -> 5347         self._protect_consolidate(f)
#    5348
#    5349     def _consolidate(self, inplace: bool_t = False):
#
# ~/.pyenv/versions/3.6.10/lib/python3.6/site-packages/pandas/core/generic.py in _protect_consolidate(self, f)
#    5334         """
#    5335         blocks_before = len(self._data.blocks)
# -> 5336         result = f()
#    5337         if len(self._data.blocks) != blocks_before:
#    5338             self._clear_item_cache()
#
# ~/.pyenv/versions/3.6.10/lib/python3.6/site-packages/pandas/core/generic.py in f()
#    5343
#    5344         def f():
# -> 5345             self._data = self._data.consolidate()
#    5346
#    5347         self._protect_consolidate(f)
#
# ~/.pyenv/versions/3.6.10/lib/python3.6/site-packages/pandas/core/internals/managers.py in consolidate(self)
#     938         bm = type(self)(self.blocks, self.axes)
#     939         bm._is_consolidated = False
# --> 940         bm._consolidate_inplace()
#     941         return bm
#     942
#
# ~/.pyenv/versions/3.6.10/lib/python3.6/site-packages/pandas/core/internals/managers.py in _consolidate_inplace(self)
#     943     def _consolidate_inplace(self):
#     944         if not self.is_consolidated():
# --> 945             self.blocks = tuple(_consolidate(self.blocks))
#     946             self._is_consolidated = True
#     947             self._known_consolidated = True
#
# ~/.pyenv/versions/3.6.10/lib/python3.6/site-packages/pandas/core/internals/managers.py in _consolidate(blocks)
#    1885     for (_can_consolidate, dtype), group_blocks in grouper:
#    1886         merged_blocks = _merge_blocks(
# -> 1887             list(group_blocks), dtype=dtype, _can_consolidate=_can_consolidate
#    1888         )
#    1889         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#
# ~/.pyenv/versions/3.6.10/lib/python3.6/site-packages/pandas/core/internals/blocks.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    3100
#    3101         argsort = np.argsort(new_mgr_locs)
# -> 3102         new_values = new_values[argsort]
#    3103         new_mgr_locs = new_mgr_locs[argsort]
#    3104
#
# MemoryError: Unable to allocate 818. MiB for an array with shape (15, 7149295) and data type int64

# %%
file = '2020-05-21-18'
train_corpus = load_corpus('/home/recsys/dataset/train_csv_v1/' + file + '/train')
test_corpus = load_corpus('/home/recsys/dataset/train_csv_v1/' + file + '/test')
cur = int(time.time())
choose_data =  pd.concat([train_corpus, test_corpus])
# Out:
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-18/train/part-00000-f23867b5-57c8-40d8-98b1-fee2456c562a-c000.csv
# /home/recsys/.pyenv/versions/3.6.10/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-18/test/part-00000-d8afc62f-ef33-49eb-8086-d5af7504d48b-c000.csv

# %%
train_by_batch(['2020-05-21-18'])
# Out:
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-18/train/part-00000-f23867b5-57c8-40d8-98b1-fee2456c562a-c000.csv
# /home/recsys/.pyenv/versions/3.6.10/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3331: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# load data from  /home/recsys/dataset/train_csv_v1/2020-05-21-18/test/part-00000-d8afc62f-ef33-49eb-8086-d5af7504d48b-c000.csv
#                                      request_id    report_time  action  \
# 40194  11e87023e25d20b4aca7c85a6447059fef32526a  1590058552000       0
# 30449  392d2eb8f0a5391a80f48c4add3822423fe66969  1590055721000       0
# 31719  076bce341395a67b13e559d3a6146987b52f2284  1590056245000       0
# 71966  957f3bef906068a04d15aeb6a444e9c15aa18434  1590056452000       0
# 54776  f4c4a473fa879cc0641f35a4977040b0bbe86283  1590056405000       0
# ...                                         ...            ...     ...
# 21488  ce64271c17a6814c23c7c58d2a0e0eef4b5ca639  1590058744000       1
# 21519  be8171fb3a41b7211b6627f8156bf4731ae872dc  1590058422000       1
# 21534  7b57234116d3a097f1fe699122c13de9cd408a75  1590055675000       1
# 21535  e89164a21f3925da0bc4437123727359ddbff5c7  1590056817000       1
# 21536  e89164a21f3925da0bc4437123727359ddbff5c7  1590057048000       1
#
#       t_language t_country    t_pid             t_ip t_channel t_scene  \
# 40194         zh        cn     dfzx   115.217.11.145       all    list
# 30449         zh        cn  dfpopup  122.192.186.142       all    list
# 31719         zh        cn     dfzx   117.136.40.222       all    list
# 71966         zh        cn     dfzx    113.46.227.90       all    list
# 54776         zh        cn     dfzx    118.114.11.24       all    list
# ...          ...       ...      ...              ...       ...     ...
# 21488         zh        cn     dfzx     27.17.42.122       car    list
# 21519         zh        cn     dfzx   106.121.179.87       all    list
# 21534         zh        cn     dfzx   36.157.152.203  military    list
# 21535         zh        cn     dfzx   120.15.151.187       all    list
# 21536         zh        cn     dfzx   120.15.151.187       all    list
#
#        t_action  ...  cp_product_type cp_is_local  cp_is_local_publisher  \
# 40194         1  ...                6           0                      0
# 30449         1  ...                6           0                      0
# 31719         1  ...                6           0                      0
# 71966         1  ...                6           0                      0
# 54776         1  ...                6           0                      0
# ...         ...  ...              ...         ...                    ...
# 21488         1  ...                6           0                      0
# 21519        23  ...                6           0                      0
# 21534        12  ...                6           0                      0
# 21535        23  ...                6           0                      0
# 21536        23  ...                6           0                      0
#
#       rs_channel rs_p1_score  rs_gactr rs_tag_interest  \
# 40194       12,3    0.414224  0.084038              颜值
# 30449          6    0.253534  0.103816             NaN
# 31719         12    0.336684  0.060736             NaN
# 71966        6,3    0.357269  0.052729             北京市
# 54776        3,1    0.091551  0.057561          美国,特朗普
# ...          ...         ...       ...             ...
# 21488       14,8    0.865334  0.666667              汽车
# 21519          6    0.062614  0.050790             NaN
# 21534         14    0.742447  0.113214              军事
# 21535          6    0.082919  0.075837             NaN
# 21536          6    0.061627  0.049647             NaN
#
#                          rs_tag_interest_dactr rs_tag_cate rs_tag_cate_dactr
# 40194                       0.1285650569701048          娱乐          0.084083
# 30449                                      NaN          汽车               NaN
# 31719                                      NaN          娱乐          0.060037
# 71966                      0.26198693737799883          国内          0.053086
# 54776  0.09482353261626067,0.10213215907310333          军事          0.057675
# ...                                        ...         ...               ...
# 21488                                      0.1          汽车          0.666667
# 21519                                      NaN          历史          0.050766
# 21534                                      0.1          军事          0.112840
# 21535                                      NaN          健康          0.075676
# 21536                                      NaN          历史          0.049617
#
# [23368 rows x 52 columns]

# %%
cur = int(time.time())
model_input = {name: choose_data[name] for name in feature_names}
for item in var_data:
    model_input[item['label']] = item['list']
    if item['label'] == 'rs_taginfo':
        model_input[item['label']+'_weight'] = item['weight']
    elif item['label'] == 'u_uli' or item['label'] == 'u_umi' or item['label'] == 'u_usi':
        model_input[item['label']+'_weight'] = item['weight']
print('cost', (int(time.time()) - cur))
# Out:
# cost 0

# %%
history = model.fit(model_input, choose_data[target].values,
                batch_size=64, epochs=5, verbose=2, validation_split=0.1)
model.save_weights('./checkpoints/'+file)

# %%
model.load_weights('./checkpoints/'+file)

# %%
# !ls {checkpoint_dir}
# Out:
# checkpoint		     cp.ckpt.data-00001-of-00002
# cp.ckpt.data-00000-of-00002  cp.ckpt.index
